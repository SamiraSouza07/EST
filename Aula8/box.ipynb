# %% [markdown]
# # <center>📦Boxplot📦</center>

# %% [markdown]
# ### Importação

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Leitura dos DFs

# %%
# leitura
alturas_A = pd.read_excel("alturas.xlsx")
alturas_B = pd.read_excel("alturasB.xlsx")
alturas_C = pd.read_excel("alturasC.xlsx")

# Catalogando as turmas
alturas_A['Turma'] = 'A'
alturas_B['Turma'] = 'B'
alturas_C['Turma'] = 'C'

# juntando as turmas
alturas_gerais = pd.concat([alturas_A,alturas_B,alturas_C])

#mostrando turmas com filtro
display(alturas_gerais.query("Turma == 'B'").sort_values(by = 'Altura'))

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(alturas_gerais,x='Turma',y='Altura', width=0.5,palette='Set2',showfliers = False,showmeans=True)
sns.stripplot(alturas_gerais,x='Turma',y='Altura',color='blue',alpha=0.2,size=7)
plt.show()
# Out:
# C:\Users\samiracampos-ieg\AppData\Local\Temp\ipykernel_12388\2366006180.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(alturas_gerais,x='Turma',y='Altura', width=0.5,palette='Set2',showfliers = False,showmeans=True)
