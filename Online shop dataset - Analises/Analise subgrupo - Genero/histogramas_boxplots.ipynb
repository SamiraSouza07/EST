# %% [markdown]
# # <center>Análise de Gênero</center>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
shopdataset_comNull = pd.read_excel('./basededados.xlsx')
# Removendo os valores null
shopdataset = shopdataset_comNull.dropna()

# %% [markdown]
# ## Média

# %%
shopdataset['Média do Pre'] = abs(shopdatase)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 shopdataset['Média do Pre'] = abs(shopdatase)
#
# NameError: name 'shopdatase' is not defined

# %% [markdown]
# # Moda do Gênero

# %%
moda = shopdataset["Gender"].mode()

print(moda)
# Out:
# 0    F
# Name: Gender, dtype: object

# %% [markdown]
# - ### Preço Médio

# %%
sns.boxplot(shopdataset, y='Gender',x='Avg_Price', showfliers=True, showmeans= True,flierprops=dict(marker='o', markersize=5, markerfacecolor='#EFA222'), color='#00CCFF')
plt.xlabel('Avg_Price')
plt.title('Gastos médio por gênero.')
sns.stripplot(shopdataset, x='Avg_Price', y='Gender', color='#5022A6', alpha=0.2, size=1)
plt.show()

# %% [markdown]
# - ### Percentual de Desconto

# %%
sns.boxplot(shopdataset, y='Gender',x='Discount_pct', showfliers=True, showmeans= True,flierprops=dict(marker='o', markersize=5, markerfacecolor='#EFA222'), color='#00CCFF')
plt.xlabel('Discount_pct')
plt.title('Percentual de disconto por gênero.')
sns.stripplot(shopdataset, x='Discount_pct', y='Gender', color='#5022A6', alpha=0.2, size=1)
plt.show()

# %% [markdown]
# - ### Gasto Offline

# %%
sns.boxplot(shopdataset, y='Gender',x='Offline_Spend', showfliers=True, showmeans= True,flierprops=dict(marker='o', markersize=5, markerfacecolor='#EFA222'), color='#00CCFF')
plt.xlabel('Offline_Spend')
plt.title('Gastos offline por gênero.')
sns.stripplot(shopdataset, x='Offline_Spend', y='Gender', color='#5022A6', alpha=0.2, size=1)
plt.show()

# %% [markdown]
# - ### Gastado Online

# %%
sns.boxplot(shopdataset, y='Gender',x='Online_Spend', showfliers=True, showmeans= True,flierprops=dict(marker='o', markersize=5, markerfacecolor='#EFA222'), color='#00CCFF')
plt.xlabel('Online_Spend')
plt.title('Gastos Online por gênero.')
sns.stripplot(shopdataset, x='Online_Spend', y='Gender', color='#5022A6', alpha=0.2, size=1)
plt.show()

# %% [markdown]
# ## <center>📶Histograma📶</center>

# %% [markdown]
# ### - Gasto Online

# %%
sns.histplot(shopdataset, x="Online_Spend", hue="Gender", multiple="stack")
# Out:
# <Axes: xlabel='Online_Spend', ylabel='Count'>

# %%
sns.histplot(shopdataset, x="Online_Spend", hue="Gender")
# Out:
# <Axes: xlabel='Online_Spend', ylabel='Count'>

# %%
print(f'A moda de gênero é {shopdataset["Gender"].mode()[0]}')
sns.histplot(shopdataset, x="Gender")
plt.show()
# Out:
# A moda de gênero é F

# %% [markdown]
# - ### Gasto Offline - Histograma

# %%
sns.histplot(shopdataset, x="Offline_Spend", hue="Gender")
# Out:
# <Axes: xlabel='Offline_Spend', ylabel='Count'>

# %%
sns.histplot(shopdataset, x="Offline_Spend", hue="Gender", multiple="stack")
# Out:
# <Axes: xlabel='Offline_Spend', ylabel='Count'>
