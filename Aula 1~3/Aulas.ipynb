# %% [markdown]
# # <center> Entendendo o ambiente </center>

# %% [markdown]
# importando as bibliotecas

# %%
import pandas as pd

# %% [markdown]
# Criando o DataFrame (DF)

# %%
df = pd.DataFrame({'Nome':['Nisfla','Santi','Modolo','Grilo','Daniel','Myrna'],
              'Aulas':[6,2,2,2,5,0],
              'Nível_Educacional':['Mestre','Mestre','Mestre','Doutorando','Mestre','Mestre'],
              'Tempo_Refeicao':[10.5,15.7,12.6,11.7,20.5,15]})
display(df)
# Out:
#      Nome  Aulas Nível_Educacional  Tempo_Refeicao
# 0  Nisfla      6            Mestre            10.5
# 1   Santi      2            Mestre            15.7
# 2  Modolo      2            Mestre            12.6
# 3   Grilo      2        Doutorando            11.7
# 4  Daniel      5            Mestre            20.5
# 5   Myrna      0            Mestre            15.0

# %% [markdown]
# # Visão Geral

# %% [markdown]
# Aula 3

# %%
display(df.dtypes)
display(df.info())
# Out:
# Nome                  object
# Aulas                  int64
# Nível_Educacional     object
# Tempo_Refeicao       float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Nome               6 non-null      object
#  1   Aulas              6 non-null      int64
#  2   Nível_Educacional  6 non-null      object
#  3   Tempo_Refeicao     6 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 324.0+ bytes
# None

# %%
display(df.isnull().sum())
# Out:
# Nome                 0
# Aulas                0
# Nível_Educacional    0
# Tempo_Refeicao       0
# dtype: int64

# %%
display(df.describe().round(2))
# Out:
#        Aulas  Tempo_Refeicao
# count   6.00            6.00
# mean    2.83           14.33
# std     2.23            3.60
# min     0.00           10.50
# 25%     2.00           11.92
# 50%     2.00           13.80
# 75%     4.25           15.52
# max     6.00           20.50

# %% [markdown]
# ### Leitura de df externo

# %%
#leitura - csv
df_transf = pd.read_csv("dataset_rh.csv", sep=";")
display(df_transf)
# Out:
#     Funcionário  Anos de Serviço  Salário Anual (R$)  \
# 0             1               13              92.489
# 1             2               16              81.504
# 2             3                1              89.866
# 3             4                4              51.723
# 4             5                4              83.890
# 5             6                8              57.591
# 6             7               10              98.146
# 7             8               19              99.300
# 8             9                5             111.557
# 9            10                7              60.006
# 10           11               13              43.560
# 11           12                2             101.713
# 12           13                7              85.444
# 13           14                8              86.522
# 14           15               15              60.737
# 15           16               18              68.647
# 16           17                6             101.353
# ...
